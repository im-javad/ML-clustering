# %% [markdown]
# # Intro

# %% [markdown]
# Hierarchy of clusters where each node is a cluster consisting of the clusters of its daughter nodes

# %% [markdown]
# ***Divisive***: is top down, so you start with all observations in a large cluster and break it down into smaller pieces <br/>
# ***Agglomerative***(populer than divisive): is the opposite of divisive. so it's bottom up, where each observation starts in its own cluster and pairs of clusters are merged together as they move up the hierarchy.<br/>
#
# ![Screenshot (301).png](attachment:7cf02263-6d75-41bc-9842-4551446abd70.png)

# %% [markdown]
# # Simple Sample

# %% [markdown]
# Finding similary of city locations in canada <br/>
# Denfrogram <br/>
# we can cut Y somwhere to have N number of clusters
#
# ![Screenshot (304).png](attachment:999b92c3-7f04-4509-8fd2-f9ff3ecf86f5.png)

# %% [markdown]
# # How does it work?

# %% [markdown]
# 1. Create n clusters, one for each data point
# 2. Compute the proximity matrix
# 3. Repeat
#     - Merge the two closest clusters
#     - Update the proximity matrix
# 4. Until only a single cluster remains
#
# ![Hierarchical-clustering-dendrogram-and-dissimilarity-matrix-A-Example-of-a.png](attachment:4d0e847e-e235-405f-8383-43ca50942883.png)

# %% [markdown]
# # Distances

# %% [markdown]
# - we should be able to calculate distances between data points (again say age, BMI, BP)
# - but also need the distance "between" clusters: <br/>
#     - single linkage clustering: minimum distance  <br/>
#     - complete linkage clustering: maximum distance  <br/>
#     - average linkage clustering: average of distances from each point to all other points  <br/>
#     - centroid linkage clustering: centroid of clusters

# %% [markdown]
# # Pros VS Cons

# %% [markdown]
# ## Pros

# %% [markdown]
# * Works with unknown N
# * Easy to implement
# * Useful dentograms, good for understanding

# %% [markdown]
# ## Cons

# %% [markdown]
# * Impossible to undo via algorithm
# * Long runtimes
# * Sometimes difficult to identify the number of clusters (specially for large datasets)

# %% [markdown]
# # Hierarchicak VS K-Means

# %% [markdown]
# * Can be slower
# * Doen't require the number of clusters to run
# * Gives more than one partitioning
# * Always generate the same clusters
